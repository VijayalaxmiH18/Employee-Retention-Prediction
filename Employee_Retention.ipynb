# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#IMPORTING LIBRARIES 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#READING DATA USING PANDAS DATAFRAME

hr_df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/hr_data.csv')

# %%
#READ TOP 5 VALUES OF DATAFRAME

hr_df.head()
# Out:
#    employee_id  number_project  ...  department  salary
# 0         1003               2  ...       sales     low
# 1         1005               5  ...       sales  medium
# 2         1486               7  ...       sales  medium
# 3         1038               5  ...       sales     low
# 4         1057               2  ...       sales     low
#
# [5 rows x 9 columns]

# %%
#CHECKING DATAFRAME SHAPE 

hr_df.shape
# Out:
# (14999, 9)

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
#CHECKING UNIQUE VALUES OF DEPARTMENT

hr_df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
#CHECKING UNIQUE VALUES OF SALARY

hr_df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
#READING SECOND DATASET USING PANDAS DATAFRAME

s_df=pd.read_excel('/content/drive/My Drive/Colab Notebooks/employee_satisfaction_evaluation.xlsx')

# %%
#CHECKING TOP 5 VALUES OF DATAFRAME

s_df.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
#JOINING BOTH THE DATAFRAMES ON THE BASIS OF ONE COMMON ROW

main_df= hr_df.set_index('employee_id').join(s_df.set_index('EMPLOYEE #'))

# %%
#CHECKING TOP 5 VALUES OF COMBINED DATASET

main_df.head()
# Out:
#              number_project  ...  last_evaluation
# employee_id                  ...
# 1003                      2  ...             0.53
# 1005                      5  ...             0.86
# 1486                      7  ...             0.88
# 1038                      5  ...             0.87
# 1057                      2  ...             0.52
#
# [5 rows x 10 columns]

# %%
#RESETTING THE INDEX OF MAIN DF

main_df=main_df.reset_index()

# %%
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
#CHECKING NULL VALUES

main_df[main_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  ...  satisfaction_level  last_evaluation
# 18            3794               2  ...                 NaN              NaN
# 19            1140               5  ...                 NaN             0.89
# 33            1230               2  ...                 NaN              NaN
# 53            1340               2  ...                 NaN              NaN
# 72           22316               2  ...                 NaN              NaN
# 92            1581               2  ...                 NaN              NaN
# 107          17376               2  ...                 NaN              NaN
# 120           1739               4  ...                 NaN              NaN
# 137           1847               2  ...                 NaN              NaN
# 175          32923               4  ...                 NaN              NaN
# 191           2160               4  ...                0.92              NaN
# ...

# %%
main_df.describe()
# Out:
#         employee_id  number_project  ...  satisfaction_level  last_evaluation
# count  14999.000000    14999.000000  ...        14972.000000     14972.000000
# mean   45424.627575        3.803054  ...            0.612830         0.716125
# std    25915.900127        1.232592  ...            0.248714         0.171138
# min     1003.000000        2.000000  ...            0.090000         0.360000
# 25%    22872.500000        3.000000  ...            0.440000         0.560000
# 50%    45448.000000        4.000000  ...            0.640000         0.720000
# 75%    67480.500000        5.000000  ...            0.820000         0.870000
# max    99815.000000        7.000000  ...            1.000000         1.000000
#
# [8 rows x 9 columns]

# %%
#FILLING NULL VALUES WITH THE MEAN VALUE

main_df.fillna(main_df.mean(),inplace=True)

# %%
#CHECKING IF THERE ARE ANY MORE NULL VALUES

main_df[main_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [employee_id, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, department, salary, satisfaction_level, last_evaluation]
# Index: []

# %%
#DROPPING REDUNDANT COLUMN

main_df.drop(columns='employee_id',inplace=True)

# %%
main_df.head()
# Out:
#    number_project  average_montly_hours  ...  satisfaction_level  last_evaluation
# 0               2                   157  ...                0.38             0.53
# 1               5                   262  ...                0.80             0.86
# 2               7                   272  ...                0.11             0.88
# 3               5                   223  ...                0.72             0.87
# 4               2                   159  ...                0.37             0.52
#
# [5 rows x 10 columns]

# %%
#COUNTING UNIQUE VALUES OF DEPARTMENT

main_df['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
#ANALYSNG DEPARTMENT COLUMN

main_df.groupby('department').sum()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                     4683  ...       879.452250
# RandD                  3033  ...       560.446125
# accounting             2934  ...       550.706125
# hr                     2701  ...       524.006125
# management             2432  ...       456.234499
# marketing              3164  ...       613.946125
# product_mng            3434  ...       644.662250
# sales                 15634  ...      2938.236749
# support                8479  ...      1611.534499
# technical             10548  ...      1961.930624
#
# [10 rows x 8 columns]

# %%
#ANALYSING DEPARTMENT COLUMN

main_df.groupby('department').mean()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                 3.816626  ...         0.716750
# RandD              3.853875  ...         0.712130
# accounting         3.825293  ...         0.718000
# hr                 3.654939  ...         0.709075
# management         3.860317  ...         0.724182
# marketing          3.687646  ...         0.715555
# product_mng        3.807095  ...         0.714703
# sales              3.776329  ...         0.709719
# support            3.803948  ...         0.722985
# technical          3.877941  ...         0.721298
#
# [10 rows x 8 columns]

# %%
#GETTING UNIQUE VALUES OF LEFT COLUMN

main_df['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
#CORRELATION MATRIX USING SNS HEATMAP

plt.figure(figsize=(12,5))
sns.heatmap(main_df.corr(),linewidths=0.5,cmap="YlGnBu",annot = True)

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='left',y='satisfaction_level',data = main_df)

#CONCLUSION : Not left -> High satisfaction level 
#             Left     -> Low satisfaction level

# %%
plt.figure(figsize=(10,8))

sns.barplot(x='left',y='average_montly_hours',data = main_df)

#CONCLUSION : Not left -> Less avg. monthly hours
#             Left     -> More avg. monthly hours

# %%
plt.figure(figsize=(10,8))

sns.barplot(x='left',y='time_spend_company',data = main_df)

#CONCLUSION : Not left -> Less time spent in company 
#             Left     -> More time spent in company

# %%
plt.figure(figsize=(10,8))

sns.barplot(x='promotion_last_5years',y='satisfaction_level',data=main_df,hue='left')

# %%
plt.figure(figsize=(19,8))

sns.barplot(x='department',y='satisfaction_level',data=main_df,hue='left')

# %%
plt.figure(figsize=(10,8))

sns.barplot(x='promotion_last_5years',y='number_project',data=main_df,hue='left')

# %%
sns.pairplot(main_df,hue='left')

# %%
plt.figure(figsize=(18,8))

sns.barplot(y='promotion_last_5years',x='department',data=main_df,hue='left')

# %%
main_df.columns
# Out:
# Index(['number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'left', 'promotion_last_5years', 'department',
#        'salary', 'satisfaction_level', 'last_evaluation'],
#       dtype='object')

# %%
main_df.head()
# Out:
#    number_project  average_montly_hours  ...  satisfaction_level  last_evaluation
# 0               2                   157  ...                0.38             0.53
# 1               5                   262  ...                0.80             0.86
# 2               7                   272  ...                0.11             0.88
# 3               5                   223  ...                0.72             0.87
# 4               2                   159  ...                0.37             0.52
#
# [5 rows x 10 columns]

# %%
#DATA PROCESSING

# %%
#GROUPING CATEGORICAL FEATURES 

y=main_df[['department','salary']]

# %%
y.head()
# Out:
#   department  salary
# 0      sales     low
# 1      sales  medium
# 2      sales  medium
# 3      sales     low
# 4      sales     low

# %%
#CONVERTING CATEGORICAL FEATURES TO NUMERICAL ONE

from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

sal_num=le.fit_transform(main_df['salary'])

# %%
sal_num
# Out:
# array([1, 2, 2, ..., 1, 1, 1])

# %%
main_df
# Out:
#        number_project  ...  last_evaluation
# 0                   2  ...             0.53
# 1                   5  ...             0.86
# 2                   7  ...             0.88
# 3                   5  ...             0.87
# 4                   2  ...             0.52
# ...               ...  ...              ...
# 14994               2  ...             0.57
# 14995               2  ...             0.48
# 14996               2  ...             0.53
# 14997               6  ...             0.96
# 14998               2  ...             0.52
#
# [14999 rows x 10 columns]

# %%
#ASSIGNING NUMERICAL SALARY COL. INTO DF

main_df['salary_num'] = sal_num

# %%
main_df
# Out:
#        number_project  average_montly_hours  ...  last_evaluation  salary_num
# 0                   2                   157  ...             0.53           1
# 1                   5                   262  ...             0.86           2
# 2                   7                   272  ...             0.88           2
# 3                   5                   223  ...             0.87           1
# 4                   2                   159  ...             0.52           1
# ...               ...                   ...  ...              ...         ...
# 14994               2                   151  ...             0.57           1
# 14995               2                   160  ...             0.48           1
# 14996               2                   143  ...             0.53           1
# 14997               6                   280  ...             0.96           1
# 14998               2                   158  ...             0.52           1
#
# [14999 rows x 11 columns]

# %%
#DROPPING CATEGORICAL SALARY VALUE 

main_df.drop(['salary'],axis=1,inplace=True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  ...  last_evaluation  salary_num
# 0                   2                   157  ...             0.53           1
# 1                   5                   262  ...             0.86           2
# 2                   7                   272  ...             0.88           2
# 3                   5                   223  ...             0.87           1
# 4                   2                   159  ...             0.52           1
# ...               ...                   ...  ...              ...         ...
# 14994               2                   151  ...             0.57           1
# 14995               2                   160  ...             0.48           1
# 14996               2                   143  ...             0.53           1
# 14997               6                   280  ...             0.96           1
# 14998               2                   158  ...             0.52           1
#
# [14999 rows x 10 columns]

# %%
#CONVERTING CATEGORICAL DEPT. COL. INTO NUMERICAL ONE

dep_num=le.fit_transform(main_df['department'])

# %%
dep_num
# Out:
# array([7, 7, 7, ..., 8, 8, 8])

# %%
#ASSIGNING NUMERICAL DEPT. COL. INTO DF

main_df['department num'] = dep_num

# %%
main_df
# Out:
#        number_project  average_montly_hours  ...  salary_num  department num
# 0                   2                   157  ...           1               7
# 1                   5                   262  ...           2               7
# 2                   7                   272  ...           2               7
# 3                   5                   223  ...           1               7
# 4                   2                   159  ...           1               7
# ...               ...                   ...  ...         ...             ...
# 14994               2                   151  ...           1               8
# 14995               2                   160  ...           1               8
# 14996               2                   143  ...           1               8
# 14997               6                   280  ...           1               8
# 14998               2                   158  ...           1               8
#
# [14999 rows x 11 columns]

# %%
#DROPPING CATEGORICAL SALARY VALUE 

main_df.drop(['department'],axis=1,inplace=True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  ...  salary_num  department num
# 0                   2                   157  ...           1               7
# 1                   5                   262  ...           2               7
# 2                   7                   272  ...           2               7
# 3                   5                   223  ...           1               7
# 4                   2                   159  ...           1               7
# ...               ...                   ...  ...         ...             ...
# 14994               2                   151  ...           1               8
# 14995               2                   160  ...           1               8
# 14996               2                   143  ...           1               8
# 14997               6                   280  ...           1               8
# 14998               2                   158  ...           1               8
#
# [14999 rows x 10 columns]

# %%
X=main_df.drop(['left'],axis=1)

# %%
X.head()
# Out:
#    number_project  average_montly_hours  ...  salary_num  department num
# 0               2                   157  ...           1               7
# 1               5                   262  ...           2               7
# 2               7                   272  ...           2               7
# 3               5                   223  ...           1               7
# 4               2                   159  ...           1               7
#
# [5 rows x 9 columns]

# %%
y=main_df['left']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: left, dtype: int64

# %%
print("The X shape is ",X.shape)
print("The y shape is ",y.shape)
# Out:
# The X shape is  (14999, 9)
# The y shape is  (14999,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,)

# %%
X_test
# Out:
#        number_project  average_montly_hours  ...  salary_num  department num
# 7825                3                   237  ...           2               9
# 1080                4                   238  ...           2               7
# 5636                4                   175  ...           2               0
# 1455                2                   155  ...           1               9
# 12434               6                   309  ...           1               8
# ...               ...                   ...  ...         ...             ...
# 3742                3                   253  ...           2               9
# 2248                4                   239  ...           2               9
# 9786                4                   203  ...           2               7
# 13685               3                   156  ...           2               6
# 1483                6                   254  ...           1               3
#
# [4500 rows x 9 columns]

# %%
X_train
# Out:
#        number_project  average_montly_hours  ...  salary_num  department num
# 2921                4                   240  ...           2               7
# 711                 2                   159  ...           1               7
# 13815               4                   222  ...           0               4
# 9331                4                   212  ...           1               7
# 12873               4                   223  ...           2               8
# ...               ...                   ...  ...         ...             ...
# 9400                4                   142  ...           2               7
# 13214               5                   217  ...           1               1
# 8191                2                   268  ...           1               7
# 13935               3                   211  ...           2               7
# 14305               6                   255  ...           1               7
#
# [10499 rows x 9 columns]

# %%
print("The X training set shape = ",X_train.shape)
print("The X testing set shape = ",X_test.shape)
# Out:
# The X training set shape =  (10499, 9)
# The X testing set shape =  (4500, 9)

# %%
from sklearn.metrics import accuracy_score

from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()

dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
prediction_dt=dt.predict(X_test)
prediction_dt
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
y_test
# Out:
# 7825     0
# 1080     1
# 5636     0
# 1455     1
# 12434    1
#         ..
# 3742     0
# 2248     0
# 9786     0
# 13685    0
# 1483     1
# Name: left, Length: 4500, dtype: int64

# %%
accuracy_dt=accuracy_score(y_test,prediction_dt)*100
print("The accuracy score using Decision Tree Classifier is ",accuracy_dt)
# Out:
# The accuracy score using Decision Tree Classifier is  97.42222222222222

# %%
Category=['Employee will stay','Employee will Leave']

# %%
custom_dt=[[1,500,3,6,0,0.90,0.89,1,8]]

# %%
Catagory[int(dt.predict(custom_dt))]
# Out:
# 'Employee will Leave'

# %%
dt.feature_importances_
# Out:
# array([1.17872028e-01, 1.29325540e-01, 1.45034509e-01, 3.27010605e-03,
#        3.90840489e-04, 4.75590574e-01, 1.13380177e-01, 6.12697670e-03,
#        9.00924932e-03])

# %%
feature_importance=pd.DataFrame(dt.feature_importances_,index=X_train.columns,columns=['Importance']).sort_values('Importance',ascending=False)

# %%
feature_importance
# Out:
#                        Importance
# satisfaction_level       0.475591
# time_spend_company       0.145035
# average_montly_hours     0.129326
# number_project           0.117872
# last_evaluation          0.113380
# department num           0.009009
# salary_num               0.006127
# Work_accident            0.003270
# promotion_last_5years    0.000391

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler().fit(X_train)
X_train_std=sc.transform(X_train)
X_test_std=sc.transform(X_test)

# %%
X_train_std
# Out:
# array([[ 0.16309154,  0.7866404 , -0.33759465, ...,  1.0187822 ,
#          1.04364789,  0.38822861],
#        [-1.47078067, -0.84070875, -0.33759465, ..., -0.96796383,
#         -0.55385308,  0.38822861],
#        [ 0.16309154,  0.42500726, -0.33759465, ..., -1.31856607,
#         -2.15135405, -0.66156849],
#        ...,
#        [-1.47078067,  1.34918084, -0.33759465, ..., -1.96133684,
#         -0.55385308,  0.38822861],
#        [-0.65384457,  0.20400922,  2.38992072, ..., -1.37699977,
#          1.04364789,  0.38822861],
#        [ 1.79696375,  1.08800135,  0.34428419, ...,  0.66817996,
#         -0.55385308,  0.38822861]])

# %%
X_test_std
# Out:
# array([[-0.65384457,  0.72636821, -1.01947349, ..., -1.26013236,
#          1.04364789,  1.08809335],
#        [ 0.16309154,  0.74645894,  1.02616304, ...,  1.36938445,
#          1.04364789,  0.38822861],
#        [ 0.16309154, -0.51925706, -1.01947349, ...,  1.19408333,
#          1.04364789, -2.06129796],
#        ...,
#        [ 0.16309154,  0.04328338, -1.01947349, ...,  0.90191479,
#          1.04364789,  0.38822861],
#        [-0.65384457, -0.90098094,  0.34428419, ..., -0.38362676,
#          1.04364789,  0.03829625],
#        [ 1.79696375,  1.06791062,  0.34428419, ...,  0.90191479,
#         -0.55385308, -1.01150086]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k_range=range(1,26)
scores={}
scores_list=[]


for k in k_range:
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_std,y_train)
    prediction_knn=knn.predict(X_test_std)
    scores[k]=accuracy_score(y_test,prediction_knn)*100
    scores_list.append(accuracy_score(y_test,prediction_knn))

# %%
scores
# Out:
# {1: 96.75555555555555,
#  2: 96.73333333333333,
#  3: 96.04444444444444,
#  4: 96.26666666666667,
#  5: 95.93333333333334,
#  6: 96.26666666666667,
#  7: 95.95555555555556,
#  8: 96.11111111111111,
#  9: 95.77777777777777,
#  10: 95.93333333333334,
#  11: 95.86666666666666,
#  12: 95.77777777777777,
#  13: 95.44444444444444,
#  14: 95.46666666666667,
#  15: 95.39999999999999,
#  16: 95.42222222222222,
#  17: 95.22222222222221,
#  18: 95.24444444444444,
#  19: 95.08888888888889,
#  20: 95.13333333333334,
#  21: 94.91111111111111,
#  22: 95.0,
#  23: 94.86666666666666,
#  24: 94.91111111111111,
#  25: 94.75555555555556}

# %%
scores_list
# Out:
# [0.9675555555555555,
#  0.9673333333333334,
#  0.9604444444444444,
#  0.9626666666666667,
#  0.9593333333333334,
#  0.9626666666666667,
#  0.9595555555555556,
#  0.9611111111111111,
#  0.9577777777777777,
#  0.9593333333333334,
#  0.9586666666666667,
#  0.9577777777777777,
#  0.9544444444444444,
#  0.9546666666666667,
#  0.954,
#  0.9542222222222222,
#  0.9522222222222222,
#  0.9524444444444444,
#  0.9508888888888889,
#  0.9513333333333334,
#  0.9491111111111111,
#  0.95,
#  0.9486666666666667,
#  0.9491111111111111,
#  0.9475555555555556]

# %%
plt.plot(k_range,scores_list)

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_std,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
prediction_knn=knn.predict(X_test_std)

# %%
accuracy_knn=accuracy_score(y_test,prediction_knn)*100

# %%
print("The accuracy using KNN is ",accuracy_knn)
# Out:
# The accuracy using KNN is  96.04444444444444

# %%
prediction_knn
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
y_test
# Out:
# 7825     0
# 1080     1
# 5636     0
# 1455     1
# 12434    1
#         ..
# 3742     0
# 2248     0
# 9786     0
# 13685    0
# 1483     1
# Name: left, Length: 4500, dtype: int64

# %%
X_knn=np.array([[20,500,10,6,0,0.10,0.30,1,8]])
X_knn_std=sc.transform(X_knn)

# %%
X_knn_std
# Out:
# array([[13.23406925,  6.01023025,  4.43555725, 16.63527561, -0.14697495,
#         -2.07145465, -2.4288065 , -0.55385308,  0.73816098]])

# %%
X_knn_prediction=knn.predict(X_knn_std)
X_knn_prediction
# Out:
# array([0])

# %%
Category[int(dt.predict(custom_dt))]
# Out:
# 'Employee will Leave'

# %%
algorithms=['Decision Tree','KNN']
scores=[accuracy_dt,accuracy_knn]
plt.xlabel("Algorithms")
plt.ylabel("Accuracy Score")
sns.barplot(algorithms,scores)
plt.show()
